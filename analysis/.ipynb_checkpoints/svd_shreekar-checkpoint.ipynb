# %% [markdown]
# # Assingment "Assignment" System for DCT Academy's Code Platform

# %% [markdown]
# ### Shreekar Hegde - User Id - 62

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
from sklearn.decomposition import TruncatedSVD
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql+psycopg2://postgres:sudhanvasud@localhost/postgres')

print(engine.table_names())
# Out:
# ['answers', 'ar_internal_metadata', 'assignment_groups', 'assignments', 'batch_students', 'batches', 'chat_rooms', 'code_play_backs', 'comments', 'courses', 'editor_settings', 'favourites', 'forks', 'friendly_id_slugs', 'list_assignments', 'lists', 'messages', 'notification_types', 'notifications', 'permissions', 'practice_students', 'practices', 'questions', 'read_questions', 'roles', 'schema_migrations', 'sections', 'solutions', 'student_courses', 'student_logs', 'students', 'submission_timers', 'submissions', 'taggings', 'tags', 'test_cases', 'users', 'videos']

# %% [markdown]
# ## Creating list of dataframe of all tables, a dictionary mapping to corresponding dataframe

# %%
# Dictionary of all the tables and their columns
table_columns = {}

# Dictionary of all dataframes mapped with table names
df_all = {}

# List of all dataframes of all tables
df_list = []

for table in engine.table_names():
    df = pd.read_sql(table, engine)
    df_all[table] = df
    df_list.append(df)
    table_columns[table] = list(df.columns)

# %% [markdown]
# ## Get Shreekar Hegde's Assignments

# %%
shreekar_submissions = df_all['submissions'][df_all['submissions']['user_id'] == 62] \
    .merge(df_all['assignments'], left_on='assignment_id', right_on='id')
shreekar_submissions.drop(['statement', 'output', 'language', 'created_at_x', 'updated_at_x', 'is_checked', 'title',
       'body', 'url', 'created_at_y', 'updated_at_y', 'user_id_y', 'source'], axis=1, inplace=True)
shreekar_submissions
# Out:
#     id_x  user_id_x  assignment_id  practice_id  time_in_seconds  pass  fail  \
# 0   1305         62             26          262              508     3     0
# 1   1721         62             26          314            44604     2     1
# 2   1311         62             34          264             1044     2     0
# 3   1319         62             23          263              343     3     0
# 4   1343         62             33          266            17304     3     0
# 5   1348         62             44          289              716     4     0
# 6   1350         62             48          291              347     3     0
# 7   1325         62             24          265             1818     4     0
# 8   1347         62             14          288              127     2     0
# 9   1349         62             17          290              255     2     0
# 10  1399         62            344          298              168     2     0
# 11  1396         62            341          297             7768     3     0
# 12  1403         62            346          299              124     3     0
# 13  1406         62            351          300              207     3     0
# 14  1407         62            352          301              226     5     0
# 15  1528         62            128          302              260     2     0
# 16  1539         62             89          304             1805     3     0
# 17  1529         62            134          303               85     2     0
# 18  1540         62            102          305              248     2     0
# 19  1546         62            122          306             3521     1     1
# 20  1702         62             80          313              515     3     0
# 21  1695         62            106          310             1412     2     0
# 22  1679         62             83          308            20334     2     0
# 23  1682         62             73          309              173     3     0
# 24  1697         62             63          307            48267     0     0
# 25  1696         62            141          311             1428     3     0
# 26  1700         62            144          312              287     2     0
# 27  1728         62             30          316            55817     2     0
# 28  1722         62            353          315              829     2     0
# 29  1774         62            121          318              683     3     0
# 30  1775         62            136          319             1854     3     0
# 31  1795         62            331          323              894     3     0
# 32  1784         62            123          320              379     5     0
# 33  1791         62             62          322              346     0     0
# 34  1793         62            357          324             1692     2     0
# 35  1878         62            174          321           196195     3     0
#
#     total  points_x  id_y  is_allowed     code  approved  points_y  minutes  \
# 0       3      10.0    26       False  DCT63a6      True        10       10
# 1       3       3.0    26       False  DCT63a6      True        10       10
# 2       2      10.0    34       False  DCT0785      True        10       15
# 3       3      10.0    23       False  DCTb800      True        10       15
# 4       3      10.0    33       False  DCT067e      True        10       15
# 5       4      10.0    44       False  DCT49ca      True        10        5
# 6       3      10.0    48       False  DCT849a      True        10       10
# 7       4      10.0    24       False  DCT6d6b      True        10       15
# 8       2      10.0    14       False  DCT31db      True        10        5
# 9       2      10.0    17       False  DCT310f      True        10       10
# 10      2      10.0   344       False  DCTc20e      True        10       15
# 11      3      10.0   341       False  DCTa7d4      True        10       10
# 12      3      10.0   346       False  DCTa27a      True        10       20
# 13      3      10.0   351       False  DCTc1ad      True        10       20
# 14      5      20.0   352       False  DCTfbc1      True        20       20
# 15      2      10.0   128       False  DCTf162      True        10       10
# 16      3      10.0    89       False  DCT68db      True        10       20
# 17      2      10.0   134       False  DCT16e2      True        10       10
# 18      2      20.0   102       False  DCTe692      True        20       20
# 19      2       5.0   122       False  DCT199f      True        10       20
# 20      3       5.0    80       False  DCTf933      True        10       10
# 21      2      20.0   106       False  DCT1a8a      True        20       20
# 22      2      10.0    83       False  DCT2914      True        10       10
# 23      3      10.0    73       False  DCT633f      True        10       10
# 24      0       0.0    63       False  DCT0188      True        20       20
# 25      3      10.0   141       False  DCT33ac      True        10       10
# 26      2       5.0   144       False  DCT1653      True        10       15
# 27      2       5.0    30       False  DCT0153      True        10       15
# 28      2      10.0   353       False  DCT2062      True        20       25
# 29      3      20.0   121       False  DCT2acd      True        20       20
# 30      3      20.0   136       False  DCT47d5      True        20       25
# 31      3      20.0   331       False  DCTddaa      True        20       10
# 32      5      20.0   123       False  DCT0601      True        20       20
# 33      0       0.0    62       False  DCTc254      True        30       30
# 34      2      20.0   357       False  DCT078a      True        20       30
# 35      3       5.0   174       False  DCT9ac5      True        10       10
#
#           function_name  input_size
# 0   findNotBookedTables         1.0
# 1   findNotBookedTables         1.0
# 2       countUpThenDown         1.0
# 3              sayAgain         2.0
# 4          authenticate         2.0
# 5               evenOdd         1.0
# 6                 iPush         2.0
# 7            vowelCount         1.0
# 8             converter         1.0
# 9            maxOfThree         3.0
# 10               findEO         1.0
# 11           abbreviate         1.0
# 12            summation         1.0
# 13            squareSum         1.0
# 14       binaryToNumber         1.0
# 15        isUpperCaseAt         2.0
# 16           stringChop         2.0
# 17           startsWith         2.0
# 18             findWord         2.0
# 19                unCap         1.0
# 20            joinArray         2.0
# 21           printArray         1.0
# 22              putDash         1.0
# 23              isArray         1.0
# 24            strWeight         2.0
# 25  removeArrayElements         2.0
# 26        randomElement         1.0
# 27         zooInventory         1.0
# 28           findUnique         1.0
# 29   sumTwoArrayIndexes         2.0
# 30          pairElement         2.0
# 31           superPower         2.0
# 32        findDuplicate         1.0
# 33            frequency         1.0
# 34            rotateStr         1.0
# 35        readingStatus         1.0
