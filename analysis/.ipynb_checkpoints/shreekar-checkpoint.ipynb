# %% [markdown]
# # Assingment "Assignment" System for DCT Academy's Code Platform

# %% [markdown]
# ### Shreekar Hegde - User Id - 62

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import functools
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql+psycopg2://postgres:sudhanvasud@localhost/postgres')

print(engine.table_names())
# Out:
# ['answers', 'ar_internal_metadata', 'assignment_groups', 'assignments', 'batch_students', 'batches', 'chat_rooms', 'code_play_backs', 'comments', 'courses', 'editor_settings', 'favourites', 'forks', 'friendly_id_slugs', 'list_assignments', 'lists', 'messages', 'notification_types', 'notifications', 'permissions', 'practice_students', 'practices', 'questions', 'read_questions', 'roles', 'schema_migrations', 'sections', 'solutions', 'student_courses', 'student_logs', 'students', 'submission_timers', 'submissions', 'taggings', 'tags', 'test_cases', 'users', 'videos']

# %% [markdown]
# ## Creating list of dataframe of all tables, a dictionary mapping to corresponding dataframe

# %%
# Dictionary of all the tables and their columns
table_columns = {}

# Dictionary of all dataframes mapped with table names
df_all = {}

# List of all dataframes of all tables
df_list = []

for table in engine.table_names():
    df = pd.read_sql(table, engine)
    df_all[table] = df
    df_list.append(df)
    table_columns[table] = list(df.columns)

# %% [markdown]
# ## Get Shreekar Hegde's Assignments

# %%
shreekar_submissions = df_all['submissions'][df_all['submissions']['user_id'] == 62] \
    .merge(df_all['assignments'], left_on='assignment_id', right_on='id')
shreekar_submissions.drop(['statement', 'output', 'language', 'created_at_x', 'updated_at_x', 'is_checked', 'title',
       'body', 'url', 'created_at_y', 'updated_at_y', 'user_id_y', 'source'], axis=1, inplace=True)
shreekar_submissions.sort_index(axis=1, inplace=True)
shreekar_submissions.to_html('shreekar.html')
shreekar_submissions['time_in_minutes'] = shreekar_submissions['time_in_seconds'] / 60 
quant = shreekar_submissions['time_in_minutes'].quantile(0.99)
shreekar_sub = shreekar_submissions[shreekar_submissions['time_in_minutes'] < quant] 
shreekar_sub['time_in_minutes'].plot(kind='hist')
plt.show()

# %% [markdown]
# ## Create a boolean difficult column based on the time taken to solve

# %%
shreekar_submissions['is_difficult'] = shreekar_submissions['minutes'] < shreekar_submissions['time_in_minutes']
shreekar_submissions
# Out:
#     approved  assignment_id     code  fail        function_name  id_x  id_y  \
# 0       True             26  DCT63a6     0  findNotBookedTables  1305    26
# 1       True             26  DCT63a6     1  findNotBookedTables  1721    26
# 2       True             34  DCT0785     0      countUpThenDown  1311    34
# 3       True             23  DCTb800     0             sayAgain  1319    23
# 4       True             33  DCT067e     0         authenticate  1343    33
# 5       True             44  DCT49ca     0              evenOdd  1348    44
# 6       True             48  DCT849a     0                iPush  1350    48
# 7       True             24  DCT6d6b     0           vowelCount  1325    24
# 8       True             14  DCT31db     0            converter  1347    14
# 9       True             17  DCT310f     0           maxOfThree  1349    17
# 10      True            344  DCTc20e     0               findEO  1399   344
# 11      True            341  DCTa7d4     0           abbreviate  1396   341
# 12      True            346  DCTa27a     0            summation  1403   346
# 13      True            351  DCTc1ad     0            squareSum  1406   351
# 14      True            352  DCTfbc1     0       binaryToNumber  1407   352
# 15      True            128  DCTf162     0        isUpperCaseAt  1528   128
# 16      True             89  DCT68db     0           stringChop  1539    89
# 17      True            134  DCT16e2     0           startsWith  1529   134
# 18      True            102  DCTe692     0             findWord  1540   102
# 19      True            122  DCT199f     1                unCap  1546   122
# 20      True             80  DCTf933     0            joinArray  1702    80
# 21      True            106  DCT1a8a     0           printArray  1695   106
# 22      True             83  DCT2914     0              putDash  1679    83
# 23      True             73  DCT633f     0              isArray  1682    73
# 24      True             63  DCT0188     0            strWeight  1697    63
# 25      True            141  DCT33ac     0  removeArrayElements  1696   141
# 26      True            144  DCT1653     0        randomElement  1700   144
# 27      True             30  DCT0153     0         zooInventory  1728    30
# 28      True            353  DCT2062     0           findUnique  1722   353
# 29      True            121  DCT2acd     0   sumTwoArrayIndexes  1774   121
# 30      True            136  DCT47d5     0          pairElement  1775   136
# 31      True            331  DCTddaa     0           superPower  1795   331
# 32      True            123  DCT0601     0        findDuplicate  1784   123
# 33      True             62  DCTc254     0            frequency  1791    62
# 34      True            357  DCT078a     0            rotateStr  1793   357
# 35      True            174  DCT9ac5     0        readingStatus  1878   174
#
#     input_size  is_allowed  minutes  pass  points_x  points_y  practice_id  \
# 0          1.0       False       10     3      10.0        10          262
# 1          1.0       False       10     2       3.0        10          314
# 2          1.0       False       15     2      10.0        10          264
# 3          2.0       False       15     3      10.0        10          263
# 4          2.0       False       15     3      10.0        10          266
# 5          1.0       False        5     4      10.0        10          289
# 6          2.0       False       10     3      10.0        10          291
# 7          1.0       False       15     4      10.0        10          265
# 8          1.0       False        5     2      10.0        10          288
# 9          3.0       False       10     2      10.0        10          290
# 10         1.0       False       15     2      10.0        10          298
# 11         1.0       False       10     3      10.0        10          297
# 12         1.0       False       20     3      10.0        10          299
# 13         1.0       False       20     3      10.0        10          300
# 14         1.0       False       20     5      20.0        20          301
# 15         2.0       False       10     2      10.0        10          302
# 16         2.0       False       20     3      10.0        10          304
# 17         2.0       False       10     2      10.0        10          303
# 18         2.0       False       20     2      20.0        20          305
# 19         1.0       False       20     1       5.0        10          306
# 20         2.0       False       10     3       5.0        10          313
# 21         1.0       False       20     2      20.0        20          310
# 22         1.0       False       10     2      10.0        10          308
# 23         1.0       False       10     3      10.0        10          309
# 24         2.0       False       20     0       0.0        20          307
# 25         2.0       False       10     3      10.0        10          311
# 26         1.0       False       15     2       5.0        10          312
# 27         1.0       False       15     2       5.0        10          316
# 28         1.0       False       25     2      10.0        20          315
# 29         2.0       False       20     3      20.0        20          318
# 30         2.0       False       25     3      20.0        20          319
# 31         2.0       False       10     3      20.0        20          323
# 32         1.0       False       20     5      20.0        20          320
# 33         1.0       False       30     0       0.0        30          322
# 34         1.0       False       30     2      20.0        20          324
# 35         1.0       False       10     3       5.0        10          321
#
#     time_in_seconds  total  user_id_x  time_in_minutes  is_difficult
# 0               508      3         62         8.466667         False
# 1             44604      3         62       743.400000          True
# 2              1044      2         62        17.400000          True
# 3               343      3         62         5.716667         False
# 4             17304      3         62       288.400000          True
# 5               716      4         62        11.933333          True
# 6               347      3         62         5.783333         False
# 7              1818      4         62        30.300000          True
# 8               127      2         62         2.116667         False
# 9               255      2         62         4.250000         False
# 10              168      2         62         2.800000         False
# 11             7768      3         62       129.466667          True
# 12              124      3         62         2.066667         False
# 13              207      3         62         3.450000         False
# 14              226      5         62         3.766667         False
# 15              260      2         62         4.333333         False
# 16             1805      3         62        30.083333          True
# 17               85      2         62         1.416667         False
# 18              248      2         62         4.133333         False
# 19             3521      2         62        58.683333          True
# 20              515      3         62         8.583333         False
# 21             1412      2         62        23.533333          True
# 22            20334      2         62       338.900000          True
# 23              173      3         62         2.883333         False
# 24            48267      0         62       804.450000          True
# 25             1428      3         62        23.800000          True
# 26              287      2         62         4.783333         False
# 27            55817      2         62       930.283333          True
# 28              829      2         62        13.816667         False
# 29              683      3         62        11.383333         False
# 30             1854      3         62        30.900000          True
# 31              894      3         62        14.900000          True
# 32              379      5         62         6.316667         False
# 33              346      0         62         5.766667         False
# 34             1692      2         62        28.200000         False
# 35           196195      3         62      3269.916667          True
