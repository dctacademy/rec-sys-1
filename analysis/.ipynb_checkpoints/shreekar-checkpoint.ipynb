# %% [markdown]
# # Assingment "Assignment" System for DCT Academy's Code Platform

# %% [markdown]
# ### Shreekar Hegde - User Id - 62

# %%
import numpy as np
import pandas as pd
import functools
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql+psycopg2://postgres:sudhanvasud@localhost/postgres')

print(engine.table_names())
# Out:
# ['answers', 'ar_internal_metadata', 'assignment_groups', 'assignments', 'batch_students', 'batches', 'chat_rooms', 'code_play_backs', 'comments', 'courses', 'editor_settings', 'favourites', 'forks', 'friendly_id_slugs', 'list_assignments', 'lists', 'messages', 'notification_types', 'notifications', 'permissions', 'practice_students', 'practices', 'questions', 'read_questions', 'roles', 'schema_migrations', 'sections', 'solutions', 'student_courses', 'student_logs', 'students', 'submission_timers', 'submissions', 'taggings', 'tags', 'test_cases', 'users', 'videos']

# %% [markdown]
# ## Creating list of dataframe of all tables, a dictionary mapping to corresponding dataframe

# %%
# Dictionary of all the tables and their columns
table_columns = {}

# Dictionary of all dataframes mapped with table names
df_all = {}

# List of all dataframes of all tables
df_list = []

for table in engine.table_names():
    df = pd.read_sql(table, engine)
    df_all[table] = df
    df_list.append(df)
    table_columns[table] = list(df.columns)

# %%
shreekar_submissions = df_all['submissions'][df_all['submissions']['user_id'] == 62] \
    .merge(df_all['assignments'], left_on='assignment_id', right_on='id')
shreekar_submissions.drop(['statement', 'output', 'user_id_x', 'language', 'assignment_id',
       'practice_id', 'created_at_x', 'updated_at_x', 'is_checked',
       'time_in_seconds', 'pass', 'fail', 'total', 'points_x', 'id_y', 'title',
       'body', 'url', 'created_at_y', 'updated_at_y', 'user_id_y', 'source',
       'is_allowed', 'code', 'approved', 'points_y', 'minutes',
       'function_name', 'input_size'], axis=1, inplace=True)
shreekar_submissions.to_html('shreekar.html')
shreekar_submissions
# Out:
#                                             statement    language  \
# 0   function findNotBookedTables(a){\n\tif(a.lengt...  javascript
# 1   \n\n\nfunction findNotBookedTables(array){\n\t...  javascript
# 2   function countUpThenDown(a){\n\tresult = [];\n...  javascript
# 3   function sayAgain(a,b){\n\tvar result = \t'';\...  javascript
# 4   function authenticate(a,b){\n\tvar result;\n\t...  javascript
# 5   function evenOdd(a){\n\tif(a.length == 0){\n\t...  javascript
# 6   function iPush(a,b){\n\tvar i;\n\tfor(i = 0; i...  javascript
# 7   function vowelCount(a){\n\tif(a.length === 0){...  javascript
# 8   function converter(a){\n\tvar store;\n\tvar ce...  javascript
# 9   function maxOfThree(a,b,c){\n\tif((a >= b) && ...  javascript
# 10  function findEO(a){\nif(a % 2 == 0){\n   retur...  javascript
# 11  function abbreviate(a){\n\tvar result = [];\n\...  javascript
# 12  function summation(a){\n\tvar sum = 0;\n\tfor(...  javascript
# 13  function squareSum(a){\n\tvar sum = 0;\n\tfor(...  javascript
# 14  function binaryToNumber(a){\n\tvar sum = 0;\n\...  javascript
# 15  function isUpperCaseAt(a,b){\n\tif(a.charAt(b)...  javascript
# 16  function stringChop(a,b){\n\tvar c= [];\n\tif(...  javascript
# 17  function startsWith(a,b){\n\tvar x = a.split('...  javascript
# 18  function findWord(a,b){\n\tvar count = 0;\n\ta...  javascript
# 19  function unCap(a){\n\tvar res = '';\n\ta = a.s...  javascript
# 20  function joinArray(array,symbol){\n\tvar newAr...  javascript
# 21  \tfunction printArray(array){\t\n\t\tvar resul...  javascript
# 22  function putDash(number){\n\tvar result = [];\...  javascript
# 23  function isArray(value){\n\tif(Array.isArray(v...  javascript
# 24  var sum1;\nvar store = [];\nvar alphabets = 'a...  javascript
# 25  function removeArrayElements(arr,ele){\n\tvar ...  javascript
# 26  function randomElement(array){\n\tif(array.len...  javascript
# 27  \n\tfunction zooInventory(array){\n\t\tvar res...  javascript
# 28  function findUnique(array){\n\tif(array.length...  javascript
# 29  function sumTwoArrayIndexes(array1,array2){\n\...  javascript
# 30  function pairElement(array,target){\n\tif(arra...  javascript
# 31  function superPower(superHeroes,name){\n\tif(n...  javascript
# 32  function findDuplicate(array){\n\tif(array.len...  javascript
# 33  function frequency(string){\n\tvar obj = {};\n...  javascript
# 34  function rotateStr(str){\n\tvar newArray = [],...  javascript
# 35  function readingStatus(library){\n\t\t\t\tres ...  javascript
#
#                  created_at_x               updated_at_x  id_y  \
# 0  2018-07-09 16:23:28.757343 2018-07-09 16:23:28.757343    26
# 1  2018-07-25 16:48:36.106752 2018-07-25 16:48:36.106752    26
# 2  2018-07-10 06:32:23.403438 2018-07-10 06:32:23.403438    34
# 3  2018-07-10 09:42:44.668082 2018-07-10 09:42:44.668082    23
# 4  2018-07-10 17:22:24.736566 2018-07-10 17:22:24.736566    33
# 5  2018-07-11 14:04:56.669331 2018-07-11 14:04:56.669331    44
# 6  2018-07-11 15:57:47.617305 2018-07-11 15:57:47.617305    48
# 7  2018-07-10 11:27:19.504793 2018-07-10 11:27:19.504793    24
# 8  2018-07-11 13:23:07.950043 2018-07-11 13:23:07.950043    14
# 9  2018-07-11 15:22:15.803020 2018-07-11 15:22:15.803020    17
# 10 2018-07-14 08:29:48.943632 2018-07-14 08:29:48.943632   344
# 11 2018-07-14 08:22:31.276283 2018-07-14 08:22:31.276283   341
# 12 2018-07-14 08:40:04.626806 2018-07-14 08:40:04.626806   346
# 13 2018-07-14 09:04:27.832152 2018-07-14 09:04:27.832152   351
# 14 2018-07-14 09:18:46.441558 2018-07-14 09:18:46.441558   352
# 15 2018-07-21 13:50:20.807910 2018-07-21 13:50:20.807910   128
# 16 2018-07-21 15:38:05.511149 2018-07-21 15:38:05.511149    89
# 17 2018-07-21 13:58:24.811484 2018-07-21 13:58:24.811484   134
# 18 2018-07-21 16:15:08.927907 2018-07-21 16:15:08.927907   102
# 19 2018-07-21 19:18:43.087858 2018-07-21 19:18:43.087858   122
# 20 2018-07-25 04:24:33.996030 2018-07-25 04:24:33.996030    80
# 21 2018-07-24 17:00:32.094884 2018-07-24 17:00:32.094884   106
# 22 2018-07-24 12:47:53.135481 2018-07-24 12:47:53.135481    83
# 23 2018-07-24 12:55:52.694316 2018-07-24 12:55:52.694316    73
# 24 2018-07-24 17:32:26.711820 2018-07-24 17:32:26.711820    63
# 25 2018-07-24 17:24:48.114813 2018-07-24 17:24:48.114813   141
# 26 2018-07-25 03:27:46.112373 2018-07-25 03:27:46.112373   144
# 27 2018-07-26 08:57:16.987320 2018-07-26 08:57:16.987320    30
# 28 2018-07-25 17:26:49.089250 2018-08-02 13:22:24.467730   353
# 29 2018-07-28 17:30:24.034837 2018-07-28 17:30:24.034837   121
# 30 2018-07-28 18:40:55.348293 2018-07-28 18:40:55.348293   136
# 31 2018-07-29 13:22:54.194104 2018-07-29 13:22:54.194104   331
# 32 2018-07-29 10:03:18.649884 2018-07-29 10:03:18.649884   123
# 33 2018-07-29 12:06:46.350129 2018-07-29 12:06:46.350129    62
# 34 2018-07-29 12:40:15.234374 2018-07-29 12:40:15.234374   357
# 35 2018-07-31 12:32:56.063280 2018-07-31 12:32:56.063280   174
#
#                                                  body url  \
# 0   <p>In this challenge, we&#39;ll use an array t...
# 1   <p>In this challenge, we&#39;ll use an array t...
# 2   <p>Create a function that takes a number as an...
# 3   <p>Create a function&nbsp;<code>sayAgain</code...
# 4   <p>Create a function,&nbsp;<code>authenticate<...
# 5   <p>Write a function that accepts and array of ...
# 6   <p>Write the function (iPush) which is a repli...
# 7   <p>Create the function&nbsp;<code>vowelCount(s...
# 8   <p>Write a converter function that accepts a t...
# 9   <p>Create the function&nbsp;<code>maxOfThree</...
# 10  <p>Create a function that takes an integer as ...
# 11  <p>Write a function to convert a name into ini...
# 12  <h1>Summation</h1>\r\n\r\n<p>Write a program t...
# 13  <p>Complete the&nbsp;<code>squareSum</code>/<c...
# 14  <p>Given an array of one&#39;s and zero&#39;s ...
# 15  <p>Write a JavaScript function to test whether...
# 16  <p>Write a JavaScript function to chop a strin...
# 17  <p>Write a JavaScript function to test whether...
# 18  <p>Write a JavaScript function to find a word ...
# 19  <p>Write a JavaScript function to Uncapitalize...
# 20  <p>Write a simple JavaScript Function to join ...
# 21  <p>Write a JavaScript program which prints the...
# 22  <p>Write a JavaScript function which accept a ...
# 23  <p>Write a JavaScript function to check whethe...
# 24  <p>You are given two strings S1 and S2. You ne...
# 25  <p>Write a JavaScript function to remove a spe...
# 26  <p><strong>&nbsp;</strong>Write a JavaScript f...
# 27  <p>Write a function&nbsp;<code>zooInventory</c...
# 28  <p>Write a function called&nbsp;<code>findUniq...
# 29  <p>There are two arrays with individual values...
# 30  <p>Write a JavaScript program to find a pair o...
