# %% [markdown]
# # Assingment "Assignment" System for DCT Academy's Code Platform

# %%
import numpy as np
import pandas as pd
import functools
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql+psycopg2://postgres:sudhanvasud@localhost/postgres')

print(engine.table_names())
# Out:
# ['answers', 'ar_internal_metadata', 'assignment_groups', 'assignments', 'batch_students', 'batches', 'chat_rooms', 'code_play_backs', 'comments', 'courses', 'editor_settings', 'favourites', 'forks', 'friendly_id_slugs', 'list_assignments', 'lists', 'messages', 'notification_types', 'notifications', 'permissions', 'practice_students', 'practices', 'questions', 'read_questions', 'roles', 'schema_migrations', 'sections', 'solutions', 'student_courses', 'student_logs', 'students', 'submission_timers', 'submissions', 'taggings', 'tags', 'test_cases', 'users', 'videos']

# %% [markdown]
# ## Creating list of dataframe of all tables, a dictionary mapping to corresponding dataframe

# %%
# Dictionary of all the tables and their columns
table_columns = {}

# Dictionary of all dataframes mapped with table names
df_all = {}

# List of all dataframes of all tables
df_list = []

for table in engine.table_names():
    df = pd.read_sql(table, engine)
    df_all[table] = df
    df_list.append(df)
    table_columns[table] = list(df.columns)

# %% [markdown]
# ## Converting dictionary of table and its columns to csv

# %%
# df_table_columns = pd.DataFrame(dict([(k, pd.Series(v)) for k,v in table_columns.items()])).fillna("")
# df_table_columns.to_csv('../assets/table_columns.csv', index=False)

# %% [markdown]
# ## Joining users, assignments, submissions table

# %%
student_users_df = df_all['users'][['id']].merge(df_all['students'][['id', 'name']], left_on='id', right_on='id')
student_users_df.columns = ['user_id', 'student_name']
student_users_df.to_html('student_users.html')
student_users_df.head()
# Out:
#    user_id          student_name
# 0       14             Indrajit
# 1       15   Pradeep Kumar Reddy
# 2       12        Aditya Nagar\t
# 3       16          Pratap Mohan
# 4       11  Sujith Kumar Reddy\t

# %%
submission_assignments_df =  df_all['submissions'][['id', 'user_id', 'assignment_id', 'time_in_seconds', 'pass', 'fail', 'total', 'points', 'is_checked']].merge(df_all['assignments'][['id', 'approved', 'points', 'minutes']], left_on='assignment_id', right_on='id')
submission_assignments_df.columns = ['user_id', 'submission_id', 'assign_id', 'time_in_seconds', 'pass', 'fail', 'total', 'points_submission',
       'is_checked', 'assignment_id', 'approved', 'points_assignment', 'minutes']
submission_assignments_df.drop(['assignment_id'], axis=1, inplace=True)
submission_assignments_df.to_html('submission_assingment.html')
submission_assignments_df.head()
# Out:
#    user_id  submission_id  assign_id  time_in_seconds  pass  fail  total  \
# 0        2             13         13                0     0     0      0
# 1        3             13         13                0     0     0      0
# 2        5             11         13                0     0     0      0
# 3        6             12         13                0     0     0      0
# 4        4             13         13                0     0     0      0
#
#    points_submission is_checked  approved  points_assignment  minutes
# 0                0.0      false      True                 20        5
# 1                0.0      false      True                 20        5
# 2                0.0       true      True                 20        5
# 3                0.0       true      True                 20        5
# 4                0.0       true      True                 20        5

# %%
student_users_df.merge(submission_assignments_df, left_on='user_id', right_on='user_id')
# Out:
#     user_id            student_name  submission_id  assign_id  \
# 0        14               Indrajit              17         13
# 1        15     Pradeep Kumar Reddy             22         31
# 2        12          Aditya Nagar\t             19         13
# 3        16            Pratap Mohan             18         31
# 4        11    Sujith Kumar Reddy\t             18         44
# 5        19         Shweta Gopinath             24         31
# 6        13        Teja Kumar Reddy             18         13
# 7        30             Pavan Kumar             13         17
# 8        21               Hasan Ali             23         31
# 9        18            Keerthana DC             20         31
# 10       25        Kartikay Dwivedi             23         55
# 11       24         Kalyan Ponugoti             17         55
# 12       22              Naman Garg             18         55
# 13       31                     Ani             14         26
# 14       20              Shan Shaji             25         31
# 15       17          Geetika Chopra             13         31
# 16       23                    test             13         55
# 17       28              Sushma D S             25         55
# 18       29             Urvashi Raj             13         26
# 19       37         Lakshmi Sravani             24         26
# 20       27       Sugama Suhasini K             24         55
# 21       41          Chetan Kailash             13         32
# 22       42               Karthik D             24         17
# 23       32        Vivek Ravindra\t             21         26
# 24       44        Shreedhar Hegade             13         34
# 25       39      Subhashree Acharya             14         33
# 26       38               Harish BN             21         30
# 27        2                    test             13         13
# 28       26                Ravi D L             20         55
# 29       54       Sai Srikant Verma             17         62
# 30       66               Sri Nitya             18         27
# 31       58          Madhu Mandanna             17         65
# 32       62     Chaitra S Bharadwaj             20         50
# 33       69          Chetan Kumar C             18         62
# 34       36                 Asha TV             14         30
# 35       52  Chenchu Lakshmi Sravya             21         47
# 36       59            Vaanu Tamaya             20         27
# 37       61          Shreekar Hegde             21         62
# 38       50      Bhagirathi Salinka             14         32
# 39       65               Ranjan HP             13         27
# 40       46            Pavan Kalyan             14         50
# 41       56                  Anup M             21         27
# 42       70         Libin Kuriakose             18         50
# 43       49            NIkhil Reddy             21         32
# 44       40              Aishwarya              14         34
# 45       55                Gaurav V             17         50
# 46       34      Pallipati Nagaraju             14         17
# 47       43               Adarsha V             13         33
# 48       68             Kavya Shree             19         62
# 49       48            Aditya Sagar             21         34
# 50       47           Pavan Shivraj             13         50
# 51       60             Prashanth K             20         62
# 52       67           Swetha Mannur             19         27
# 53       45        Vijaykumar R Pai             21         33
# 54       35                 Dhanush             21         17
# 55       64            Irawati Gole             20         65
#
#     time_in_seconds  pass  fail  total  points_submission      is_checked  \
# 0                 0     0     0      0                0.0           false
# 1               523     0     0      0                0.0           false
# 2                 0     0     0      0                0.0       incorrect
# 3               918     0     0      0                0.0  partial output
# 4                 0     0     0      0                0.0         correct
# 5               510     0     0      0                0.0         correct
# 6                 0     0     0      0                0.0           false
# 7               331     0     0      0                0.0       incorrect
# 8                82     0     0      0                0.0         correct
# 9              1423     0     0      0                0.0         correct
# 10              763     0     0      0                0.0         correct
# 11              919     0     0      0                0.0         correct
# 12              903     0     0      0                0.0         correct
# 13              760     0     0      0                0.0         correct
# 14               85     0     0      0                0.0         correct
# 15              830     0     0      0                0.0         correct
# 16              910     0     0      0                0.0  partial output
# 17             2035     0     0      0                0.0         correct
# 18              775     0     0      0                0.0         correct
# 19             3433     0     0      0                0.0         correct
# 20             1889     0     0      0                0.0           false
# 21             4443     0     0      0                0.0         correct
# 22             3057     0     0      0                0.0       incorrect
# 23             1511     0     0      0                0.0           false
# 24             1202     0     0      0                0.0  partial output
# 25              874     0     0      0                0.0         correct
# 26              505     0     0      0                0.0           false
# 27                0     0     0      0                0.0           false
# 28             1939     0     0      0                0.0           false
# 29              511     0     0      0                0.0         correct
# 30             2235     0     0      0                0.0         correct
# 31             2267     0     0      0                0.0         correct
# 32              881     0     0      0                0.0         correct
# 33             1100     0     0      0                0.0         correct
# 34             1591     0     0      0                0.0         correct
# 35              938     0     0      0                0.0         correct
# 36             1486     0     0      0                0.0         correct
# 37             6566     0     0      0                0.0         correct
# 38            52482     0     0      0                0.0         correct
# 39             8522     0     0      0                0.0         correct
# 40             2440     0     0      0                0.0         correct
# 41             8199     0     0      0                0.0         correct
# 42             1241     0     0      0                0.0         correct
# 43            19749     0     0      0                0.0           false
# 44              541     0     0      0                0.0         correct
# 45             1321     0     0      0                0.0         correct
# 46              798     0     0      0                0.0         correct
# 47             1144     0     0      0                0.0           false
# 48              524     0     0      0                0.0  partial output
# 49            11548     0     0      0                0.0           false
# 50             3699     0     0      0                0.0       incorrect
# 51              898     0     0      0                0.0         correct
# 52              839     0     0      0                0.0  partial output
# 53              893     0     0      0                0.0           false
# 54             2055     0     0      0                0.0           false
# 55             1972     0     0      0                0.0         correct
#
#     approved  points_assignment  minutes
# 0       True                 20        5
# 1       True                 10       10
# 2       True                 20        5
# 3       True                 10       10
# 4       True                 10        5
# 5       True                 10       10
# 6       True                 20        5
# 7       True                 10       10
# 8       True                 10       10
# 9       True                 10       10
# 10      True                 20        5
# 11      True                 20        5
# 12      True                 20        5
# 13      True                 10       10
# 14      True                 10       10
# 15      True                 10       10
# 16      True                 20        5
# 17      True                 20        5
# 18      True                 10       10
# 19      True                 10       10
# 20      True                 20        5
# 21      True                 10       10
# 22      True                 10       10
# 23      True                 10       10
# 24      True                 10       15
# 25      True                 10       15
# 26      True                 10       15
# 27      True                 20        5
# 28      True                 20        5
# 29      True                 30       30
# 30      True                 20       20
# 31      True                 20       20
# 32      True                 20       20
# 33      True                 30       30
# 34      True                 10       15
# 35      True                 10        5
# 36      True                 20       20
# 37      True                 30       30
# 38      True                 10       10
# 39      True                 20       20
# 40      True                 20       20
# 41      True                 20       20
# 42      True                 20       20
# 43      True                 10       10
# 44      True                 10       15
# 45      True                 20       20
# 46      True                 10       10
# 47      True                 10       15
# 48      True                 30       30
# 49      True                 10       15
# 50      True                 20       20
# 51      True                 30       30
# 52      True                 20       20
# 53      True                 10       15
# 54      True                 10       10
# 55      True                 20       20
