# %% [markdown]
# # Assignment "Assignment" System for DCT Academy's Code Platform

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql+psycopg2://postgres:sudhanvasud@localhost/postgres')

print(engine.table_names())
# Out:
# ['answers', 'ar_internal_metadata', 'assignment_groups', 'assignments', 'batch_students', 'batches', 'chat_rooms', 'code_play_backs', 'comments', 'courses', 'editor_settings', 'favourites', 'forks', 'friendly_id_slugs', 'list_assignments', 'lists', 'messages', 'notification_types', 'notifications', 'permissions', 'practice_students', 'practices', 'questions', 'read_questions', 'roles', 'schema_migrations', 'sections', 'solutions', 'student_courses', 'student_logs', 'students', 'submission_timers', 'submissions', 'taggings', 'tags', 'test_cases', 'users', 'videos']

# %% [markdown]
# ## Creating list of dataframe of all tables, a dictionary mapping to corresponding dataframe

# %%
# Dictionary of all the tables and their columns
table_columns = {}

# Dictionary of all dataframes mapped with table names
df_all = {}

# List of all dataframes of all tables
df_list = []

for table in engine.table_names():
    df = pd.read_sql(table, engine)
    df_all[table] = df
    df_list.append(df)
    table_columns[table] = list(df.columns)

# %% [markdown]
# ## Get all student/user assignments
# ### Merge submissions, assignments, taggings, tags

# %%
user_submissions = df_all['submissions'] \
    .merge(df_all['assignments'], left_on='assignment_id', right_on='id', suffixes=('_submissions', '_assignments')) \
    .merge(df_all['taggings'], left_on='assignment_id', right_on='taggable_id', suffixes=('_sub_ass', '_taggings')) \
    .merge(df_all['tags'], left_on='tag_id', right_on='id', suffixes=('_sub_ass_tag', '_tags')) 
user_submissions.drop(['statement', 'output', 'language', 'created_at_submissions', 'updated_at_submissions', 'is_checked', 'body', 'url', 
                       'created_at_assignments', 'updated_at_assignments', 'pass', 'fail', 'tagger_type', 'created_at', 'total', 'practice_id', 
                       'assignment_id', 'user_id_assignments', 'code', 'points_assignments', 'tagger_id', 'tag_id', 'source', 'input_size', 
                       'taggable_type', 'approved', 'function_name', 'context', 'id_sub_ass_tag', 'taggings_count', 'is_allowed'], axis=1, inplace=True)

# %%
user_submissions.columns
# Out:
# Index(['id_submissions', 'user_id_submissions', 'time_in_seconds',
#        'points_submissions', 'id_assignments', 'title', 'minutes',
#        'taggable_id', 'id_tags', 'name'],
#       dtype='object')

# %%
user_submissions.head()
# Out:
#    id_submissions  user_id_submissions  time_in_seconds  points_submissions  \
# 0               2                   13                0                 0.0
# 1               3                   13                0                 0.0
# 2               5                   11                0                 0.0
# 3               6                   12                0                 0.0
# 4               4                   13                0                 0.0
#
#    id_assignments              title  minutes  taggable_id  id_tags  name
# 0              13  Merge two strings        5           13        2  easy
# 1              13  Merge two strings        5           13        2  easy
# 2              13  Merge two strings        5           13        2  easy
# 3              13  Merge two strings        5           13        2  easy
# 4              13  Merge two strings        5           13        2  easy

# %%
user_submissions.describe()
# Out:
#        id_submissions  user_id_submissions  time_in_seconds  \
# count     8226.000000          8226.000000     8.226000e+03
# mean       949.351082            42.140895     9.450106e+04
# std        570.111182            15.050899     4.499981e+05
# min          1.000000             3.000000    -4.487700e+04
# 25%        426.250000            34.000000     3.270000e+02
# 50%        935.000000            43.000000     9.330000e+02
# 75%       1433.000000            52.000000     3.684000e+03
# max       1972.000000            71.000000     4.924741e+06
#
#        points_submissions  id_assignments      minutes  taggable_id  \
# count         8217.000000     8226.000000  8226.000000  8226.000000
# mean             6.924415       96.267688    13.752735    96.267688
# std              6.738542      105.487078     6.571127   105.487078
# min              0.000000       13.000000     5.000000    13.000000
# 25%              0.000000       30.000000    10.000000    30.000000
# 50%              5.000000       48.000000    15.000000    48.000000
# 75%             10.000000      124.000000    20.000000   124.000000
# max             50.000000      358.000000    60.000000   358.000000
#
#            id_tags
# count  8226.000000
# mean     11.581571
# std       5.535404
# min       1.000000
# 25%       7.000000
# 50%      13.000000
# 75%      16.000000
# max      25.000000

# %%
user_submissions['name'] = user_submissions['name'].str.replace('/',',')

# %%
plt.figure(figsize=(20, 10))
# user_submissions.groupby(['title']).count()['time_in_seconds'].plot(kind='hist')
plt.xticks(rotation='30')
plt.hist(user_submissions['time_in_seconds'], bins=np.arange(0, 5000000, 200000))
# plt.title('All assignments vs time in seconds')
# plt.xlabel('Time distribution')
# plt.ylabel('No of Assignments')
plt.show()

# %%
user_submissions[user_submissions['time_in_seconds'] < 0]
# Out:
#       id_submissions  user_id_submissions  time_in_seconds  \
# 72              1673                   70           -43645
# 234             1472                   70           -37168
# 280             1620                   70           -41557
# 422              561                   48           -43306
# 438             1474                   70           -44070
# 439             1475                   70           -44070
# 626              863                   48            -1431
# 708             1472                   70           -37168
# 773              839                   48             -383
# 802              524                   48           -42871
# 815              496                   48           -44734
# 833              561                   48           -43306
# 849             1474                   70           -44070
# 850             1475                   70           -44070
# 863              487                   48           -43160
# 884              533                   48           -44133
# 919              543                   48           -43028
# 980             1037                   48           -43785
# 1046             868                   48            -1725
# 1188             863                   48            -1431
# 1273            1676                   70           -44630
# 1274            1676                   70           -44630
# 1333            1026                   48           -43910
# 1403            1476                   70           -43840
# 1450            1473                   70           -44078
# 1471            1610                   70           -42918
# 1537            1472                   70           -37168
# 1641            1051                   48           -44787
# 1695             778                   48            -1684
# 1696             778                   48            -1684
# ...              ...                  ...              ...
# 6547            1475                   70           -44070
# 6555             775                   48            -1710
# 6569             777                   48            -1307
# 6644            1673                   70           -43645
# 6723             863                   48            -1431
# 6775            1476                   70           -43840
# 6822            1473                   70           -44078
# 6847             839                   48             -383
# 6975            1676                   70           -44630
# 7019            1473                   70           -44078
# 7102             778                   48            -1684
# 7118            1666                   70           -44877
# 7132             775                   48            -1710
# 7133             775                   48            -1710
# 7184            1934                   70           -42789
# 7339            1026                   48           -43910
# 7409            1476                   70           -43840
# 7444             778                   48            -1684
# 7460            1666                   70           -44877
# 7501             839                   48             -383
# 7574            1934                   70           -42789
# 7644            1676                   70           -44630
# 7661             778                   48            -1684
# 7677            1666                   70           -44877
# 7683             775                   48            -1710
# 7743            1473                   70           -44078
# 7803             971                   48           -43704
# 8037            1026                   48           -43910
# 8074             777                   48            -1307
# 8176             971                   48           -43704
#
#       points_submissions  id_assignments                       title  minutes  \
# 72                   5.0              44                Even and Odd        5
# 234                  2.0              23                   Say Again       15
# 280                 10.0             106                 Print Array       20
# 422                  5.0              24            Count the Vowels       15
# 438                  5.0              24            Count the Vowels       15
# 439                  5.0              24            Count the Vowels       15
# 626                 10.0              31            Reverse a String       10
# 708                  2.0              23                   Say Again       15
# 773                 10.0              35                   Fizz Buzz       10
# 802                  0.0              69            convert to array       10
# 815                  0.0              68      string is blank or not       10
# 833                  5.0              24            Count the Vowels       15
# 849                  5.0              24            Count the Vowels       15
# 850                  5.0              24            Count the Vowels       15
# 863                  0.0              67               string or not       10
# 884                  0.0              71  string in abbreviated form       10
# 919                  0.0              93             Repeat a string       10
# 980                 20.0             102                 Find a word       20
# 1046                 5.0              66               String or Not       10
# 1188                10.0              31            Reverse a String       10
# 1273                 5.0              17                Max Of Three       10
# 1274                 5.0              17                Max Of Three       10
# 1333                 5.0              30               Zoo Inventory       15
# 1403                 2.0              33             Authenticate!!!       15
# 1450                 5.0              34          Count Up then Down       15
# 1471                10.0              73                Array or not       10
# 1537                 2.0              23                   Say Again       15
# 1641                10.0              80         Join Array Elements       10
# 1695                 5.0              14       Temperature Converter        5
# 1696                 5.0              14       Temperature Converter        5
# ...                  ...             ...                         ...      ...
# 6547                 5.0              24            Count the Vowels       15
# 6555                10.0              20             Is it Divisible        5
# 6569                10.0              28                    Only One        5
# 6644                 5.0              44                Even and Odd        5
# 6723                10.0              31            Reverse a String       10
# 6775                 2.0              33             Authenticate!!!       15
# 6822                 5.0              34          Count Up then Down       15
# 6847                10.0              35                   Fizz Buzz       10
# 6975                 5.0              17                Max Of Three       10
# 7019                 5.0              34          Count Up then Down       15
# 7102                 5.0              14       Temperature Converter        5
# 7118                 5.0              14       Temperature Converter        5
# 7132                10.0              20             Is it Divisible        5
# 7133                10.0              20             Is it Divisible        5
# 7184                 5.0             344            Find Even or Odd       15
# 7339                 5.0              30               Zoo Inventory       15
# 7409                 2.0              33             Authenticate!!!       15
# 7444                 5.0              14       Temperature Converter        5
# 7460                 5.0              14       Temperature Converter        5
# 7501                10.0              35                   Fizz Buzz       10
# 7574                 5.0             344            Find Even or Odd       15
# 7644                 5.0              17                Max Of Three       10
# 7661                 5.0              14       Temperature Converter        5
# 7677                 5.0              14       Temperature Converter        5
# 7683                10.0              20             Is it Divisible        5
# 7743                 5.0              34          Count Up then Down       15
# 7803                30.0              56         Objectifying Arrays       30
# 8037                 5.0              30               Zoo Inventory       15
# 8074                10.0              28                    Only One        5
# 8176                30.0              56         Objectifying Arrays       30
#
#       taggable_id  id_tags                 name
# 72             44        2                 easy
# 234            23        2                 easy
# 280           106        2                 easy
# 422            24        2                 easy
# 438            24        2                 easy
# 439            24        2                 easy
# 626            31        7              strings
# 708            23        7              strings
# 773            35        7              strings
# 802            69        7              strings
# 815            68        7              strings
# 833            24        7              strings
# 849            24        7              strings
# 850            24        7              strings
# 863            67        7              strings
# 884            71        7              strings
# 919            93        7              strings
# 980           102        7              strings
# 1046           66        7              strings
# 1188           31       13                basic
# 1273           17       13                basic
# 1274           17       13                basic
# 1333           30       13                basic
# 1403           33       13                basic
# 1450           34       13                basic
# 1471           73       13                basic
# 1537           23       13                basic
# 1641           80       13                basic
# 1695           14       13                basic
# 1696           14       13                basic
# ...           ...      ...                  ...
# 6547           24       14                 prep
# 6555           20       14                 prep
# 6569           28       14                 prep
# 6644           44       23                  es6
# 6723           31       18                loops
# 6775           33       18                loops
# 6822           34       18                loops
# 6847           35       18                loops
# 6975           17       10              numbers
# 7019           34       10              numbers
# 7102           14       10              numbers
# 7118           14       10              numbers
# 7132           20       10              numbers
# 7133           20       10              numbers
# 7184          344       10              numbers
# 7339           30        8           conditions
# 7409           33        8           conditions
# 7444           14        8           conditions
# 7460           14        8           conditions
# 7501           35        8           conditions
# 7574          344        8           conditions
# 7644           17        1                 ruby
# 7661           14        1                 ruby
# 7677           14        1                 ruby
# 7683           20        1                 ruby
# 7743           34       15  hashes , js objects
# 7803           56       15  hashes , js objects
# 8037           30       22            variables
# 8074           28       22            variables
# 8176           56        3               medium
#
# [153 rows x 10 columns]

# %%
df_all['submissions'][df_all['submissions']['time_in_seconds'] < 0].describe()
# Out:
#                 id    user_id  assignment_id  practice_id  time_in_seconds  \
# count    30.000000  30.000000      30.000000    30.000000        30.000000
# mean   1067.333333  55.633333      79.733333   239.400000    -30728.700000
# std     443.296922  11.363837      91.987980    42.388678     19710.801196
# min     487.000000  35.000000      14.000000   171.000000    -44877.000000
# 25%     775.500000  48.000000      25.000000   199.000000    -44030.000000
# 50%     919.500000  48.000000      50.000000   243.000000    -43094.000000
# 75%    1474.750000  70.000000      78.250000   265.000000     -1713.750000
# max    1934.000000  70.000000     344.000000   310.000000       -56.000000
#
#             pass       fail      total     points
# count  30.000000  30.000000  30.000000  30.000000
# mean    1.966667   0.233333   2.200000   7.066667
# std     1.272612   0.626062   1.297212   6.679528
# min     0.000000   0.000000   0.000000   0.000000
# 25%     1.000000   0.000000   2.000000   3.500000
# 50%     2.000000   0.000000   2.000000   5.000000
# 75%     2.750000   0.000000   3.000000  10.000000
# max     4.000000   2.000000   4.000000  30.000000

# %%
df_all['submissions'].min()
# Out:
# id                                                                 1
# statement          \tfunction printArray(array){\t\n\t\tvar resul...
# output                                                         False
# user_id                                                            3
# language                                                  javascript
# assignment_id                                                     13
# practice_id                                                        3
# created_at                                2018-01-10 12:10:37.095249
# updated_at                                2018-06-06 14:51:20.347692
# is_checked                                                   correct
# time_in_seconds                                               -44877
# pass                                                               0
# fail                                                               0
# total                                                              0
# points                                                             0
# dtype: object
